# %% [markdown]
# <a href="https://colab.research.google.com/github/NonStop8988/DZ2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Читаем
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df.head(n = 10)

# %%
df.shape

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
df.dtypes

# %%
df.columns

# %% [markdown]
# **Выборка данных**

# %%
df[['latitude', 'population']]

# %% [markdown]
# **Задание**: Необходимо вывести столбец total_rooms, у которого медианный возраст
# здания(housing_median_age) меньше 20.

# %%
df

# %%
df[df['housing_median_age'] < 20]

# %%
df[(df['housing_median_age'] < 20) & (df['housing_median_age'] > 10)][['total_rooms', 'housing_median_age']]

# %% [markdown]
# **Простая статистика**

# %% [markdown]
# Вывод максимального значения

# %%
print(df['population'].max())

# %% [markdown]
# Вывод минимального значения

# %%
print(df['population'].min())

# %% [markdown]
# Вывод среднего значения

# %%
print(df['population'].mean())

# %% [markdown]
# Вывод суммы по стобцу

# %%
print(df['population'].sum())

# %% [markdown]
# Нахождение среднего значения для каждого из указанных столбцов

# %%
df[['population', 'total_rooms']].median()

# %% [markdown]
# **Для получения сразу всей информации**

# %%
df.describe()

# %% [markdown]
# **count** - общее количество непустых строк
# **mean** - среднее значение столбца
# **srd** - стандартное отклонение от среднего
# **min** - минимальное значение
# **max** - максимальное значение
# числа 25%, 50%, 75% - перцентили
# **перцентиль** - показатель статистики, показывающий значение, ниже которого падает определенный процент наблюдений в группе наблюжений

# %% [markdown]
# **Изображаем статистические отношения**

# %%
import seaborn as sns

# %% [markdown]
# Изображение точек долготы по отношению к широте:

# %%
sns.scatterplot(data=df, x="longitude", y="latitude")

# %%
df

# %%
sns.scatterplot(data=df, x="households", y="population", hue="total_rooms")

# %%
size = 10 - для изменения размера точек

# %%
sns.scatterplot(data=df, x="households", y="population", hue="total_rooms", size = 10)

# %% [markdown]
# График показывается с помощью функции .map()
# .scatterplot - это использование точечных графиков

# %%
cols = ['population', 'median_income', 'housing_median_age',
'median_house_value']
g = sns.PairGrid(df[cols])
g.map(sns.scatterplot)

# %% [markdown]
# kind - указываем, что будет линия

# %%
sns.relplot(x="latitude", y="median_house_value", kind="line", data=df)

# %%
sns.relplot(x = 'longitude', y = 'median_house_value', kind = 'line', data = df)

# %%
sns.scatterplot(data=df, x="latitude", y="longitude", hue="median_house_value")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
sns.histplot(data=df, x="median_income")
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.histplot(data=df[df['housing_median_age']>50], x="median_income")
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %%
df.loc[df['housing_median_age'] <= 20, 'age_group'] = 'Молодые'
df.loc[(df['housing_median_age'] > 20) & (df['housing_median_age'] <= 50),
'age_group'] = 'Ср. возраст'
df.loc[df['housing_median_age'] > 50, 'age_group'] = 'Пожилые'

# %%
df.groupby('age_group')['median_income'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='age_group'>

# %%
df.loc[df['median_income'] > 6, 'income_group'] = 'rich'
df.loc[df['median_income'] < 6, 'income_group'] = 'everyone_else'

# %%
sns.displot(df, x="median_house_value", hue="income_group")
